# %%
import pandas as pd 
iphone=pd.read_csv("C:/Users/ASUS/Desktop/nlp/iphone.csv")

# %%
iphone
# Out:
#      productAsin country        date  isVerified  ratingScore  \
# 0     B09G9BL5CP   India  11-08-2024        True            4
# 1     B09G9BL5CP   India  16-08-2024        True            5
# 2     B09G9BL5CP   India  14-05-2024        True            4
# 3     B09G9BL5CP   India  24-06-2024        True            5
# 4     B09G9BL5CP   India  18-05-2024        True            5
# ...          ...     ...         ...         ...          ...
# 3057  B09G9D8KRQ   India  11-10-2023        True            1
# 3058  B09G9D8KRQ   India  14-10-2022        True            2
# 3059  B09G9D8KRQ   India  24-02-2022        True            3
# 3060  B09G9D8KRQ   India  16-10-2023        True            1
# 3061  B09G9D8KRQ   India  11-11-2023        True            1
#
#                               reviewTitle  \
# 0                              No charger
# 1                         iPhone 13 256GB
# 2                 Flip camera option nill
# 3                                 Product
# ...

# %%
iphone.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3062 entries, 0 to 3061
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   productAsin        3062 non-null   object
#  1   country            3062 non-null   object
#  2   date               3062 non-null   object
#  3   isVerified         3062 non-null   bool
#  4   ratingScore        3062 non-null   int64
#  5   reviewTitle        3062 non-null   object
#  6   reviewDescription  2976 non-null   object
#  7   reviewUrl          3046 non-null   object
#  8   reviewedIn         3062 non-null   object
#  9   variant            3062 non-null   object
#  10  variantAsin        3062 non-null   object
# dtypes: bool(1), int64(1), object(9)
# memory usage: 242.3+ KB

# %% [markdown]
# # 1.1 Computing with Language: Texts and Words

# %%
import nltk

# %% [markdown]
# ## Searching Text

# %%
iphone["reviewDescription"]=iphone["reviewDescription"].astype(str)

# %%
nltk.Text(iphone["reviewDescription"][0])
# Out:
# <Text: E v e r y   t h...>

# %%
" ".join(iphone["reviewDescription"]).split()
# Out:
# ['Every',
#  'thing',
#  'is',
#  'good',
#  'about',
#  'iPhones,',
#  "there's",
#  'nothing',
#  'compared',
#  'to',
#  "it's",
#  'speed',
#  'and',
#  'ios',
#  'but',
#  'i',
#  'was',
#  'disappointed',
#  'because',
#  "there's",
#  'no',
#  'charger',
#  'for',
#  'it',
#  'even',
#  'though',
#  'Indian',
#  'judiciary',
#  'told',
#  'them',
#  'to',
#  'provide',
#  ',',
#  'still',
#  'they',
#  "haven't",
#  'made',
#  'any',
#  'progress',
#  'regarding',
#  'charger.',
#  'Why',
#  'should',
#  'we',
#  'spend',
#  '62k',
#  'and',
#  'more',
#  'than',
#  'that',
#  'for',
#  'iPhones',
#  'because',
#  'of',
#  "it's",
#  'brand',
#  'and',
#  'Acessories',
#  'comfort',
#  'size',
#  'and',
#  'Features',
#  'right',
#  'if',
#  "that's",
#  'not',
#  'there',
#  "what's",
#  'point',
#  'of',
#  'buying',
#  'an',
#  'iPhone.Thank',
#  'you🙏',
#  'It',
#  'look',
#  'so',
#  'fabulous,',
#  'I',
#  'am',
#  'android',
#  'user',
#  'switched',
#  'to',
# ...

# %%
text = nltk.Text(" ".join(iphone["reviewDescription"]).split())

# Belirli bir kelimenin metin içindeki geçtiği yerleri göster
text.concordance("Every")
# Out:
# Displaying 25 of 74 matches:
#  Every thing is good about iPhones, there's
# ing BGMI you loose around 2% battery every 6minutes at HD + Extreme Graphics. W
# s complete number is typed. Each and every thingLove this Product I liked the w
# eded my already high expectations in every way. Here's why I am thoroughly impr
# sive, ensuring I get the most out of every charge.iOS: The iPhone 13 runs on iO
# p-tier mobile experience. It's worth every penny and more! USB cable was defect
# 8GB has surpassed my expectations in every aspect, setting a new standard for s
# ell you, it's been a game-changer in every way!Screen: The display is absolutel
# .3. Andorid Dialer is Always Missed: Every android has a basic feature, where y
# 8GB has surpassed my expectations in every aspect, setting a new standard for s
# .3. Andorid Dialer is Always Missed: Every android has a basic feature, where y
#  system, or impressive battery life, every aspect of this phone feels well-thou
# ...
